# %% [markdown]
# # ***O Pêndulo Simples***

# %% [markdown]
# Consideremos agora outro sistema $-$ o movimento de uma massa presa ao teto por uma haste, o conhecido Pêndulo Simples!
#
# ![Pendulo.png](data:image/png;base64,...)
